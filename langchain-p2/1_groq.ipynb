# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain_groq
#   Downloading langchain_groq-1.1.3-py3-none-any.whl.metadata (2.9 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in C:\Users\divya\AppData\Roaming\Python\Python314\site-packages (from langchain_groq) (1.5.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\ProgramData\anaconda3\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\ProgramData\anaconda3\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\ProgramData\anaconda3\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\ProgramData\anaconda3\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.13.4)
# Requirement already satisfied: sniffio in C:\Users\divya\AppData\Roaming\Python\Python314\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in C:\ProgramData\anaconda3\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.16.0)
# Requirement already satisfied: idna>=2.8 in C:\ProgramData\anaconda3\Lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.18)
# Requirement already satisfied: certifi in C:\ProgramData\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\ProgramData\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\ProgramData\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\divya\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\divya\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.10.17)
# Requirement already satisfied: packaging>=23.2.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\divya\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\ProgramData\anaconda3\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\divya\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in C:\Users\divya\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\divya\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\ProgramData\anaconda3\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (2.7.0)
# Downloading langchain_groq-1.1.3-py3-none-any.whl (20 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
# Installing collected packages: groq, langchain_groq
#
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 2/2 [langchain_groq]
#
# Successfully installed groq-0.37.1 langchain_groq-1.1.3

# %%
import os 
from dotenv import load_dotenv
from langchain_groq import ChatGroq
load_dotenv()
groq_api_key = os.getenv("GROQ_API_KEY")
model = ChatGroq(model="llama-3.1-8b-instant",groq_api_key = groq_api_key)
model
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.5.3', 'langchain': '1.3.14'}}, output_version=None, profile={'name': 'Llama 3.1 8B Instant', 'release_date': '2024-07-23', 'last_updated': '2024-07-23', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 131072, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x0000029E0E9CD2B0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000029E0E9CFCB0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
from langchain_core.messages import HumanMessage,SystemMessage
messages = [
    SystemMessage(content = "Translate the following from english to sanskrit"),
    HumanMessage(content = "Hello how are you? ")
]
result = model.invoke(messages)

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()
parser.invoke(result)
# Out:
# 'नमस्ते कस्ति आप? \n\nHere\'s a breakdown of the translation:\n\n- नमस्ते (Namaste): This is a Sanskrit greeting that roughly translates to "hello," "good morning," "good evening," or "goodbye." It\'s a respectful way to greet someone, often used in Indian and Nepali cultures.\n\n- कस्ति (Kasti): This is the Sanskrit equivalent of "how," often used in the sense of "how are you." However, it\'s more common to use the phrase कस्ति आप (Kasti aap), where आप (Aap) is a formal way of saying "you."\n\nSo, the full translation is "Namaste, kasti aap?"'

# %%
# Using LCEL we can chain components 
chain = model | parser 
chain.invoke(messages)
# Out:
# 'नमस्ते कस्तोतु? \n\nTranslation:\n- नमस्ते (Namaste) - Hello/ Greeting\n- कस्तोतु (Kashtot) - How are you? \n\nNote: In Sanskrit, the language structure and grammatical usage can vary based on the context. The translation given above is in the most commonly used Sanskrit greeting style.\n\nFor a more formal or traditional Sanskrit greeting, you can use:\n\n"नमस्ते त्वम् कस्तोतु? " (Namaste tvam kastotu) \n\n- नमस्ते (Namaste) - Hello/ Greeting\n- त्वम् (Tvam) - You (formal)\n- कस्तोतु (Kastotu) - How are you?'

# %%
from langchain_core.prompts import ChatPromptTemplate

# 1. Define the template properly
generic_template = "Translate the following into {language}"
prompt = ChatPromptTemplate.from_messages([
    ("system", generic_template),
    ("user", "{text}")
])

chain = prompt | model | parser

final_output = chain.invoke({"language": "sanskrit", "text": "Hi how are you? "})
print(final_output)
# Out:
# You can translate the given sentence into Sanskrit as follows:
#
# "Namaskāra. Kutas tvam?"
#
# Breakdown:
# - "Namaskāra" (नमस्कार): a greeting equivalent to "hello" or "hi"
# - "Kutas" (कुतः): meaning "where" or "how"
# - "Tvam" (त्वम्): meaning "you"
#
# So, the entire sentence "Hi how are you?" translates to "Namaskāra, kutas tvam?" in Sanskrit.
#
# However, if you want a more direct translation of "how are you?", it would be:
#
# "Kuto 'si?"
#
# Breakdown:
# - "Kuto" (कुतः): meaning "how" or "where" (in a general sense)
# - "'si" (असि): a verb meaning "are you" or "exist you"
#
# So, "how are you?" translates to "Kuto 'si?" in Sanskrit.
#
# In a more formal or poetic style, you could use:
#
# "Katham tvam asti?"
#
# Breakdown:
# - "Katham" (कथम्): meaning "how" or "what"
# - "Tvam" (त्वम्): meaning "you"
# - "Asti" (अस्ति): a verb meaning "are" or "exist"

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastapi in C:\Users\divya\AppData\Roaming\Python\Python314\site-packages (0.141.1)
# Requirement already satisfied: starlette>=0.46.0 in C:\ProgramData\anaconda3\Lib\site-packages (from fastapi) (1.3.1)
# Requirement already satisfied: pydantic>=2.9.0 in C:\ProgramData\anaconda3\Lib\site-packages (from fastapi) (2.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in C:\ProgramData\anaconda3\Lib\site-packages (from fastapi) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\ProgramData\anaconda3\Lib\site-packages (from fastapi) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\ProgramData\anaconda3\Lib\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic>=2.9.0->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic>=2.9.0->fastapi) (2.46.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in C:\ProgramData\anaconda3\Lib\site-packages (from starlette>=0.46.0->fastapi) (4.12.1)
# Requirement already satisfied: idna>=2.8 in C:\ProgramData\anaconda3\Lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (3.18)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: uvicorn in C:\ProgramData\anaconda3\Lib\site-packages (0.40.0)
# Requirement already satisfied: click>=7.0 in C:\Users\divya\AppData\Roaming\Python\Python314\site-packages (from uvicorn) (8.4.2)
# Requirement already satisfied: h11>=0.8 in C:\ProgramData\anaconda3\Lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in C:\ProgramData\anaconda3\Lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
