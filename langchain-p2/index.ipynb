# %%
import os 
from dotenv import load_dotenv
load_dotenv()
from langchain_google_genai import ChatGoogleGenerativeAI
os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY") 
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")
llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    temperature=1.0,  
    max_tokens=None,
    timeout=None,
    max_retries=2
)
llm.invoke("What is gen AI?")

## Input and get response from llm
# Out:
# C:\Users\divya\AppData\Roaming\Python\Python314\site-packages\langchain_google_genai\chat_models.py:3120: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# AIMessage(content=[{'type': 'text', 'text': '**Generative AI (Gen AI)** is a type of artificial intelligence that can **create new content**—including text, images, audio, video, code, and 3D models—in response to simple text prompts.\n\nTo understand Gen AI, it helps to contrast it with **Traditional AI**:\n\n*   **Traditional AI** analyzes existing data to find patterns, make predictions, or classify things. *(Example: Predicting weather, recommending a movie on Netflix, or detecting spam emails.)*\n*   **Generative AI** goes a step further by using those patterns to **build something brand new** that didn\'t exist before. *(Example: Writing a poem about the weather, generating an original image of a cat in space, or writing a custom piece of software code.)*\n\n---\n\n### How Does Gen AI Work?\n\n1.  **Training:** A Gen AI model is fed vast amounts of data (like millions of books, articles, photos, or lines of code).\n2.  **Learning Patterns:** The AI analyzes this data to understand relationships, style, grammar, and concepts (e.g., learning what a "dog" looks like or how a "polite email" sounds).\n3.  **Generating (Predicting):** When you give the AI a "prompt" (an instruction), it uses complex math to predict what words, pixels, or sounds should come next, generating a unique response. \n\nThink of it as an extremely sophisticated version of "autocomplete" on your smartphone, but capable of writing an entire essay or drawing a photorealistic picture.\n\n---\n\n### Popular Examples of Gen AI Tools\n\n*   **Text & Chat:** OpenAI’s **ChatGPT**, Anthropic’s **Claude**, Google’s **Gemini** (used for writing, summarizing, brainstorming, and translation).\n*   **Images:** **Midjourney**, **DALL-E 3**, **Stable Diffusion** (used to create digital art, marketing graphics, and realistic photos from text descriptions).\n*   **Video:** **OpenAI Sora**, **Runway** (creates short video clips from text prompts).\n*   **Code:** **GitHub Copilot** (helps programmers write code faster).\n*   **Audio/Music:** **Suno**, **ElevenLabs** (generates realistic human voices or composes original music).\n\n---\n\n### Why is Gen AI Such a Big Deal?\n\n*   **Accessibility:** You don\'t need to know how to code to use it. Anyone can talk to a Gen AI tool in plain, natural language.\n*   **Speed and Efficiency:** Tasks that used to take hours (like drafting a report, designing a logo, or translating a document) can now be done in seconds.\n*   **Idea Generation:** It acts as a digital brainstorming partner for creators, businesses, and scientists.\n\n---\n\n### What are the Limitations and Risks?\n\nDespite its capabilities, Gen AI has notable drawbacks:\n\n*   **"Hallucinations":** Gen AI models can state false information with absolute confidence because they predict what *sounds* right rather than checking for truth.\n*   **Copyright & Ethics:** Models are trained on work created by human artists, writers, and programmers, raising questions about intellectual property rights.\n*   **Bias:** If the training data contains societal biases, the AI will reproduce those biases in its output.\n*   **Misinformation & Deepfakes:** Gen AI makes it easy to create believable fake news, realistic fake photos, and audio impersonations for scams.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ff500-a4ff-7633-bc96-97a2f9288828-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 1639, 'total_tokens': 1645, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 905}})

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system","You are an expert AI engineer provide me answer based on these"),
    ("user","{input}")
])
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI engineer provide me answer based on these'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## Combine 
chain = prompt|llm
response=chain.invoke({"input":"Can you tell me about langsmith? "})
print(response)
print(type(response))
# Out:
# C:\Users\divya\AppData\Roaming\Python\Python314\site-packages\langchain_google_genai\chat_models.py:3120: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# content=[{'type': 'text', 'text': 'As an AI engineer, I view **LangSmith** as one of the most critical tools in the modern **LLMOps (Large Language Model Operations)** stack. \n\nCreated by **LangChain**, LangSmith is a specialized platform designed to help developers **debug, test, evaluate, and monitor** LLM applications—from the initial prototyping phase all the way through to enterprise production.\n\nHere is a comprehensive breakdown of what LangSmith is, the problem it solves, its core capabilities, and how it fits into AI engineering workflows.\n\n---\n\n### The Problem LangSmith Solves\n\nBuilding applications powered by LLMs (RAG systems, autonomous agents, complex chains) is inherently non-deterministic. Traditional Application Performance Monitoring (APM) tools like Datadog or New Relic track network latency and server errors, but they **cannot show you**:\n1. What the exact prompt sent to the model was.\n2. Why an agent made a specific tool call decision.\n3. How much token usage (and cost) a specific nested step incurred.\n4. Whether a model’s response suffered from hallucinations or context degradation.\n\nLangSmith acts as a "microscope" for your LLM calls, turning black-box model interactions into transparent, traceable execution trees.\n\n---\n\n### Core Capabilities of LangSmith\n\n#### 1. Advanced Tracing and Debugging\nWhen an LLM pipeline fails or gives a bad answer, you need to see the exact execution path.\n* **Execution Trees:** Visualizes nested steps (e.g., User Query $\\rightarrow$ Embedding Model $\\rightarrow$ Vector Store Retrieval $\\rightarrow$ Prompt Formatting $\\rightarrow$ LLM Call).\n* **Granular Data:** Displays exact inputs, outputs, system messages, function/tool calls, latency per step, and token costs.\n* **Time Travel Debugging:** Allows you to edit a prompt mid-chain directly inside the LangSmith UI and rerun that specific step to see how the output changes.\n\n#### 2. Evaluation and Testing (Evals)\nEvaluating non-deterministic software requires new paradigms. LangSmith simplifies setting up regression tests before deploying code.\n* **Dataset Creation:** Easily convert production logs or failure cases into test datasets with a single click.\n* **Evaluators:** Supports multiple evaluation paradigms:\n  * **Heuristic/Rule-based:** Regex matching, length checks, JSON schema validation.\n  * **LLM-as-a-Judge:** Uses powerful models (like GPT-4) to grade responses on criteria like correctness, toxicity, or context relevance.\n  * **Human-in-the-Loop:** Allows human annotators to label outputs (e.g., thumbs up/down, feedback scores).\n\n#### 3. Production Monitoring and Observability\nOnce your app is live, LangSmith shifts into a real-time monitoring tool.\n* **Cost & Latency Tracking:** Track P50/P99 latencies, token consumption, and dollar costs broken down by model, user, or environment.\n* **Online Feedback Collections:** Capture end-user feedback (e.g., user clicked "thumbs down") and automatically associate it with the exact trace that generated the response.\n* **Drift Detection:** Monitor for drops in answer quality or spikes in latency over time.\n\n#### 4. Prompt Engineering & Playground\n* Integrated playground to test and tweak prompts against multiple models (OpenAI, Anthropic, local models via Ollama) side-by-side.\n* Includes a **Prompt Hub** to version, pull, and push prompts collaboratively across a team.\n\n---\n\n### Framework Agnostic (Not Just for LangChain)\n\nA common misconception is that you *must* use the `langchain` Python/JS library to use LangSmith. **This is false.**\n\nWhile it offers zero-setup integration with LangChain, you can use LangSmith with **any framework** (e.g., LlamaIndex, AutoGen, CrewAI, DSPy) or raw API calls (OpenAI, Anthropic) using:\n* Python / JavaScript SDK decorators (`@traceable`).\n* OpenTelemetry standard exports.\n* Direct REST APIs.\n\n#### Example: Raw OpenAI with LangSmith Tracing\n\n```python\nimport os\nfrom langsmith import  ...
# <class 'langchain_core.messages.ai.AIMessage'>

# %%
#str output parser 

from langchain_core.output_parsers import StrOutputParser 
output_parser = StrOutputParser()
chain = prompt|llm|output_parser
response = chain.invoke({"input":"Can you tell me inheritance in javascript?"})
print(response)
# Out:
# C:\Users\divya\AppData\Roaming\Python\Python314\site-packages\langchain_google_genai\chat_models.py:3120: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# In JavaScript, **inheritance** is the mechanism by which one object can access properties and methods from another object.
#
# Unlike traditional Class-based Object-Oriented languages (like Java or C++), JavaScript natively uses **Prototypal Inheritance**. Even though modern JavaScript uses the `class` keyword, it is merely **syntactic sugar** built on top of prototype chains.
#
# Here is a complete breakdown of how inheritance works in JavaScript, from modern syntax to deep under-the-hood mechanisms.
#
# ---
#
# ### 1. The Core Concept: The Prototype Chain
#
# Every JavaScript object has an internal, hidden property called `[[Prototype]]` (accessible via `Object.getPrototypeOf()` or historical `__proto__`).
#
# When you try to access a property or method on an object:
# 1. JS looks at the **object itself**.
# 2. If it doesn't find it, it checks the object's **`[[Prototype]]`**.
# 3. It continues up the chain until it finds the property or reaches `null`.
# 4. If it reaches `null` and hasn't found it, it returns `undefined`.
#
# ---
#
# ### 2. Modern Way: ES6 Classes (`extends` and `super`)
#
# Introduced in ES6 (2015), this is the standard, modern way to handle inheritance in JavaScript.
#
# ```javascript
# // Parent Class (Base Class)
# class Animal {
#   constructor(name) {
#     this.name = name;
#   }
#
#   eat() {
#     console.log(`${this.name} is eating.`);
#   }
# }
#
# // Child Class (Subclass)
# class Dog extends Animal {
#   constructor(name, breed) {
#     // 1. super() calls the parent's constructor
#     super(name);
#     this.breed = breed;
#   }
#
#   // Adding a new method
#   bark() {
#     console.log(`${this.name} says: Woof!`);
#   }
#
#   // Method Overriding
#   eat() {
#     // Call parent method if needed using super
#     super.eat();
#     console.log(`${this.name} eats rapidly!`);
#   }
# }
#
# const myDog = new Dog('Buddy', 'Golden Retriever');
#
# myDog.bark(); // Output: Buddy says: Woof!
# myDog.eat();  // Output: Buddy is eating. -> Buddy eats rapidly!
# ```
#
# #### Key Keywords:
# * **`extends`**: Sets up the prototype chain so `Dog.prototype` inherits from `Animal.prototype`.
# * **`super()`**: Calls the parent constructor. You **must** call `super()` in a derived class constructor before using `this`.
#
# ---
#
# ### 3. Under the Hood: Pure Prototypal Inheritance
#
# To understand what JavaScript is *actually* doing behind the scenes, you can create objects directly from other objects using `Object.create()`.
#
# ```javascript
# const animalPrototype = {
#   eat() {
#     console.log(`${this.name} is eating.`);
#   }
# };
#
# // Create a new object that links directly to animalPrototype
# const dog = Object.create(animalPrototype);
# dog.name = "Rex";
# dog.bark = function() {
#   console.log("Woof!");
# };
#
# dog.eat(); // Output: Rex is eating. (Inherited from animalPrototype)
# ```
#
# Here, `dog` has no `eat()` method of its own. It delegate-calls `animalPrototype.eat()`.
#
# ---
#
# ### 4. Legacy ES5 Way: Constructor Functions
#
# Before ES6 `class`, developers used constructor functions and manually wired up `.prototype`. You will still see this in legacy codebases.
#
# ```javascript
# // Parent Constructor
# function Animal(name) {
#   this.name = name;
# }
#
# Animal.prototype.eat = function() {
#   console.log(this.name + " is eating.");
# };
#
# // Child Constructor
# function Dog(name, breed) {
#   Animal.call(this, name); // Steal parent constructor properties
#   this.breed = breed;
# }
#
# // Inherit the parent prototype methods
# Dog.prototype = Object.create(Animal.prototype);
#
# // Reset the constructor reference back to Dog
# Dog.prototype.constructor = Dog;
#
# Dog.prototype.bark = function() {
#   console.log("Woof!");
# };
# ```
#
# ---
#
# ### 5. Property Shadowing
#
# If a child object defines a property or method with the **exact same name** as one on its parent prototype, the child's property "shadows" (overrides) the parent's.
#
# ```javascript
# class Parent {
#   greet() { console.log("Hello from Parent"); }
# }
#
# class Child extends Parent {
#   greet() { console.log("Hello from Child"); } // Shadowing
# }
#
# const c = new Child();
# c.greet(); // "Hello from Child"
# ```
#
# ---
#
# ### Senior Engineer Best Practices & Gotchas
#
# 1. **Class is Syntactic Sugar:** Always remember `class` is not a true class like in Java. `typeof Dog` returns `"function"`.
# 2. **Favor Composition over Deep Inheritance:** Avoid deep inheritance trees (e.g., `Dog` -> `Canine` -> `Mammal` -> `Animal` -> `Organism`). Deep chains cause tight coupling, fragile code, and performance lookup costs.
# 3. **Performance:** Checking properties that do not exist requires walking the entire prototype chain down to `null`, which can impact performance in hot code paths.
# 4. **`hasOwnProperty()`:** Use `Object.hasOwn(obj, 'prop')` to check if a property belongs to the object instance itself rather than its prototype chain.
