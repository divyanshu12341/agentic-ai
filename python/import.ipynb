# %%
from packages.math import addition
addition(2,3)
# Out:
# 5

# %%
#Standard library 
# Vast collection of modules and packages that come bundled with python.
# Provides wide range of functionalities out of the box 

#Array,math,random,os
import array
import math
import random
import os
import shutil
import json
import csv
from datetime import datetime,timedelta
import time
import re

arr = array.array('i',[1,2,3,4])
print(arr)
print(math.sqrt(16))
print(random.randint(1,10))
print(random.choice(['Apple','Banana','Cherry']))
print(os.getcwd())
shutil.copyfile('requirements.txt','destination.txt')
data = {'name':'Divyanshu',
        'age':26}
str_json = json.dumps(data)
print(str_json)
print(type(str_json))
parsed_data = json.loads(str_json)
with open('example.csv',mode = 'w',newline='') as file:
     writer = csv.writer(file)
     writer.writerow(['name','age'])
     writer.writerow(['Divyanshu',26])

with open('example.csv',mode = 'r') as file:
     reader = csv.reader(file)
     for row in reader:
          print(row)

#current time
now = datetime.now()
print(now)
yesterday = now - timedelta(days=1)
print(yesterday)

print(time.time())
time.sleep(2)
print(time.time())
pattern = r'\d+'
text = 'There are 123 apples'
match = re.search(pattern,text)
print(match.group())
# Out:
# array('i', [1, 2, 3, 4])
# 4.0
# 2
# Cherry
# d:\Development\gen-ai\python
# {"name": "Divyanshu", "age": 26}
# <class 'str'>
# <class 'dict'>
# ['name', 'age']
# ['Divyanshu', '26']
# 2026-08-06 11:25:43.554607
# 2026-08-05 11:25:43.554607
# 1785995743.554832
# 1785995745.5557914
# 123
