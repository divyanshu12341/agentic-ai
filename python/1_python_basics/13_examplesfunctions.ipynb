# %%
def convert_temperature(temp,unit):
    """This function converts temperature between celsius and farenheit"""
    if unit == 'C':
        return (temp*(9/5)+32) ##Celsius to farenheit 
    elif unit == 'F':
        return (temp-32)*5/9

temp=convert_temperature(25,'C')
temp2 = convert_temperature(77,'F')
temp2
# Out:
# 25.0

# %%
def is_strong_password(password):
    """This function checks whether password is strong or not"""
    if(len(password)<8):
        return False;
    if not any(char.isdigit() for char in password):
        return False;
    if not any(char.islower() for char in password):
        return False;
    if not any(char.isUpper() for char in password):
        return False;
    if not any(char in '@#$%^&{}()_+' for char in password):
        return False
    return True;       

is_strong_password("Weak")
is_strong_password("Str@0#aaababA")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 16
#      12         return False
#      13     return True;
#      14
#      15 is_strong_password("Weak")
# ---> 16 is_strong_password("Str@0#aaababA")
#
# Cell In[4], line 9, in is_strong_password(password)
#       5     if not any(char.isdigit() for char in password):
#       6         return False;
#       7     if not any(char.islower() for char in password):
#       8         return False;
# ----> 9     if not any(char.isUpper() for char in password):
#      10         return False;
#      11     if not any(char in '@#$%^&{}()_+' for char in password):
#      12         return False
#
# Cell In[4], line 9, in is_strong_password.<locals>.<genexpr>(.0)
# ----> 9     if not any(char.isUpper() for char in password):
#
# AttributeError: 'str' object has no attribute 'isUpper'

# %%
def calculate_total_cost(cart):
    total_cost = 0
    for item in cart:
        total_cost +=item['price']*item['quantity']
    return total_cost;

## Example cart data 
cart = [
    {'name':'Apple','price':0.5,'quantity':4},
    {'name':'Banana','price':0.3,'quantity':6},
    { 'name':'Orange','price':0.7,'quantity':7}
]
print(calculate_total_cost(cart))
# Out:
# 8.7

# %%
# Check if string is a palindrome 
def check_palindrome(str):
    return str == str[::-1]

check_palindrome("nana")
# Out:
# False

# %%
# Factorial of a number using recursion 
# 5! = 5x4x3x2x1

def find_fact(n):
    if n==0: return 1;
    return n*find_fact(n-1)
ans = find_fact(5)
ans
# Out:
# 120

# %%
# Function to read a file and count frequency of each word 
def count_word_freq(file_path):
    word_count = {}
    with open(file_path,'r') as file:
        for line in file:
            words = line.split()
            for word in words:
                word = word.lower().strip()
                word_count[word] = word_count.get(word,0)+1
    return word_count

filepath = "13_file.txt"
word_frequency = count_word_freq(filepath)
word_frequency
# Out:
# {'hello': 1, 'my': 1, 'name': 1, 'is': 1, 'divyanshu': 3}
