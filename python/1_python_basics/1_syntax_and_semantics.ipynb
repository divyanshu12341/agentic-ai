# %%
# Out:
# Krish
# Krishn

# %%
## Indentation: 
## Python uses indentation to define blocks of code. 
## Consistent use of spaces or a tab is required.

age = 32
if age>30:
    print(age)

# %%
## Line continuation: 
## Use a backslash(\) for line continuation. 

total= 1 + 2 + 3 + 4 + 5 + \
    6 + 7
print(total)
# Out:
# 28

# %%
## Multiple statements on a single line: 
x = 5; y = 10; z = x+y
print(x+y);
# Out:
# 15

# %%
## Understand semantics in python: 
## Type inferencing(Dynamic typing
age = 30; ## integer 

name = "Divyanshu" ##string
print(type(age))
# Out:
# <class 'int'>

# %%
# Code example of indentations : 
if True:
    print("Correct indentation")
    if False:
        print("This won't print")
    print("Still inside first if-block")
# Out:
# Correct indentation
# Still inside first if-block
