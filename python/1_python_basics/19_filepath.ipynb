# %%
import os
#Create a new directory
new_directory = "package"
os.mkdir(new_directory)
print("Directory:{new_directory} created")
# Out:
# Directory:{new_directory} created

# %%
# Listing files and directories 
items = os.listdir('.')
print(items)
# Out:
# ['10_dictionaries.ipynb', '11_tuples.ipynb', '12_functions.ipynb', '13_examplesfunctions.ipynb', '13_file.txt', '14_lambdafunctions.ipynb', '14_mapfunction.ipynb', '16_filterfunction.ipynb', '17_importmodules.ipynb', '18_file_operations.ipynb', '19_filepath.ipynb', '1_syntax_and_semantics.ipynb', '2_variables.ipynb', '3_data_types.ipynb', '4_operators.ipynb', '5_conditional_statements.ipynb', '6_loops.ipynb', '7_lists.ipynb', '8_list_examples.ipynb', '9_sets.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'package']

# %%
# Joining path 
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name,file_name)
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# d:\Development\gen-ai\python\1_python_basics\folder\file.txt

# %%
path = 'example1.txt'
if os.path.exists(path):
    print("Exists")
else:
    print("Doesn't exist")
# Out:
# Doesn't exist

# %%
# Check if a path is file or directory 
path = 'example1.txt'
if os.path.isfile(path):
    print("It is a file")
elif os.path.isdir(path):
    print("It is a directory")
else:
    print("This path is neither file nor directory")
# Out:
# This path is neither file nor directory
