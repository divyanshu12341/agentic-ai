# %%
## Operators in python:

# %%
## Arithmetic operations: 
a = 10
b = 5
add_result = a + b  ##addition
sub_result = a - b  ##subtraction
prod_result = a * b  ##multiplication
div_result = a/b    ##division
floor_div_result = a // b ##floor division
modulus_result = a % b   ##modulus operation
exponential_result = a ** b  ##exponential operation

print("Addition: ",add_result)
print("Subtraction: ",sub_result)
print("Multiplication: ",prod_result)
print("Division: ",div_result)
print("Floor Division: ",floor_div_result)
print("Modulus: ",modulus_result)
print("Exponential: ",exponential_result)
# Out:
# Addition:  15
# Subtraction:  5
# Multiplication:  50
# Division:  2.0
# Floor Division:  2
# Modulus:  0
# Exponential:  100000

# %%
## Comparison operators: 
## ==
a = 10;b=10;
result = (a == b) ##True 
print(result)
str1="Krish";str2="krish"
result2=(str1 == str2)
print(result2)

## !=
str1!=str2

## greater than >
num1 = 45;num2 = 55
result3 = (num1>num2)
print(result3)

## less than <
result4 = (num1<num2)
print(result4)

## greater than or equal to >= 
number1 = 45;number2 = 45
result5 = (number1>=number2)
print(result5)

## less than or equal to <+ 
result6 = (number1<=number2)
print(result6)
# Out:
# True
# False
# False
# True
# True
# True

# %%
## Logical operators;

# %%
## AND,OR,NOT
## In case of AND Operation,if both values are true then only it will return true
X = True; Y = True;
result1 = X and Y
print(result)
## In case of OR Operation,if any one value is true then it will return true 
X = False; Y = False;
result2 = X or Y;
print(result2)

## NOT operator reverses the boolean value 
print(not X)
# Out:
# True
# False
# True
