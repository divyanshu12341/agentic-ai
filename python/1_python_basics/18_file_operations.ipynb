# %%
## Read a whole file 
with open('example.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# Hello how are you? Are you learning this

# %%
## Read a file line by line 
with open('example.txt','r') as file:
    for line in file:
        print(line)
# Out:
# Hello how are you? Are you learning this
#
# H
#
# B
#
# A
#
# C
#
# C
#
# H
#
# A

# %%
# writing a file 
with open('example.txt','w') as file:
    file.write("Hello what's up \n This is a new line" )

# %%
#writing a file without overwriting 
with open('example.txt','a') as file:
    file.write('Now i am writing something')

# %%
#Writing list of lines into file 
lines = ['First line \n','Second line \n',' Third line \n']
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
#Binary files 
#Writing
data = b'\x00\x01\x02\x03\x04'
with open('example.bin','wb') as file:
    file.write(data)

# %%
#Reading 
with open('example.bin','rb') as file:
    content = file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
# Reading from one file and writing it to another file 
with open('example.txt','r') as file:
    content = file.read()

with open('destination.txt','w') as file:
    file.write(content)

# %%
with open('example.txt','w+') as file:
    file.write('Hello my friends \n')
    file.write('How are you')
    # move cursor to beginning
    file.seek(0)
    content = file.read()
    print(content)
# Out:
# Hello my friends
# How are you
