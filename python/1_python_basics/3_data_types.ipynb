# %%
## Data Types

# %%
## Integer: 
age = 25
type(age)

# %%
## floating point datatype: 
height = 5.11
type(height)

# %%
## String datatype: 
name = "Divyanshu"
type(name)

# %%
## Boolean datatype: 
a = 10;b=10;
is_True = True 
type(is_True)
type(a == b)

# %%
## common errors while working with data types:
result = "Hello" + 5; ## TypeError: can only concatenate str (not "int") to str
result = "Hello" + str(5); ## correct way to concatenate strings
