# %%
# Inheritance is a fundamental method in object oriented programming 
# that allows a class to inherit methods and attributes from another
# class
# Parent class 
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows = windows 
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f"The persion will drive {self.enginetype} car")

class Tesla(Car):
    def __init__(self,doors,windows,enginetype,is_selfdriving):
        
        super().__init__(windows,doors,enginetype )
        self.is_selfdriving = is_selfdriving
    def selfdriving(self):
        print(f"Tesla supports self driving: {self.is_selfdriving}")

Car1 = Car(4,5,'Petrol')
print(Car1.drive())
# Out:
# The persion will drive Petrol car
# None

# %%
tesla1 = Tesla(4,5,'Electric',True)
tesla1.selfdriving()
tesla2 = Tesla(5,6,'Petrol',False)
tesla2.selfdriving()
# Out:
# Tesla supports self driving: True
# Tesla supports self driving: False

# %%
## Multiple inheritance:
## When a class inherits from more than one base class 
class Animal:
    def __init__(self,name):
        self.name = name
    def speak(self):
        print("Subclass must implement this method"
              )

## Base class 2 
class Pet:
    def __init__(self,owner):
        self.owner = owner

## Sub class 
class Dog(Animal,Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)

    def speak(self):
        return f"{self.name} says woof"

## create an object 
dog = Dog("Buddy","Krish")
print(dog.speak())
print(f"Owner:{dog.owner}")
# Out:
# Buddy says woof
# Owner:Krish
