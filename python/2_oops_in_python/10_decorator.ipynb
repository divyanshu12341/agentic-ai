# %%
# Allows to modify behaviour of a function or class method 
# Commonly used to add functionality without modifying original code
# function copy 
def welcome():
    return "Welcome to the advanced python course"
wel = welcome
wel()

del welcome
wel()
# Out:
# 'Welcome to the advanced python course'

# %%
# Closures functions 

def main_welcome():
    msg = "Welcome"
    def sub_welcome_method():
        print("Welcome to advanced python course")
        print("Please learn these methods properly")
    return sub_welcome_method()
main_welcome()
# Out:
# Welcome to advanced python course
# Please learn these methods properly

# %%
def main_welcomes(func):
    def sub_welcome_method():
        print("Welcome to advance python course")
        func("Welcome everyone in this tutorial")
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
#Decorators
@main_welcomes
def course_introduction():
    print("This is an advanced python course")
# Out:
# Welcome to advance python course
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #Decorators
# ----> 2 @main_welcomes
#       3 def course_introduction():
#       4     print("This is an advanced python course")
#
# Cell In[11], line 6, in main_welcomes(func)
#       2     def sub_welcome_method():
#       3         print("Welcome to advance python course")
#       4         func("Welcome everyone in this tutorial")
#       5         print("Please learn these concepts properly")
# ----> 6     return sub_welcome_method()
#
# Cell In[11], line 4, in main_welcomes.<locals>.sub_welcome_method()
#       2     def sub_welcome_method():
#       3         print("Welcome to advance python course")
# ----> 4         func("Welcome everyone in this tutorial")
#       5         print("Please learn these concepts properly")
#
# TypeError: course_introduction() takes 0 positional arguments but 1 was given
