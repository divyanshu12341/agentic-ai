# %%
# Encapsulation involves bundling data and methods that operate on the data 
# within single unit while abstraction involves hiding complex implementation 
# details and exposing only unnecessary features 

#Encapsulations involves wrapping data and methods in a single unit.
# It restricts direct access to some of the object components which means 
# preventing accidental interference and misuse of data

# public,protected,private variables:
# _ --> protected variable 
# __ --> Private variable 

class Person:
    def __init__(self,name,age,username,email):
        self.name = name 
        self.age = age
        self.__username = username
        self._email = email

class employee(Person):
    def __init__(self,name,age,username,email):
            super().__init__(name,age,username,email)




# Username is private variable 
person = Person("Divyanshu",26,"divj1231",'a')
def get_name(person):
    return person.name
print(person.name)
# print(person.username)
print(get_name(person)) 
emp = employee("A",26,"b","cc")
# Out:
# Divyanshu
# Divyanshu
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 35
#      31 print(person.name)
#      32 # print(person.username)
#      33 print(get_name(person))
#      34 emp = employee("A",26,"b","cc")
# ---> 35 print(emp.email)
#
# AttributeError: 'employee' object has no attribute 'email'

# %%
# encapsulation with getter and setter 
class Person:
    def __init__(self,name,age):
        self.__name = name
        self.__age = age

## getter method for name
    def get_name(self):
        return self.__name

## setter method for name 
    def set_name(self,name):
        self.__name = name

## getter method for age 
    def get_age(self):
        return self.__age
    def set_age(self,age):
        self.__age = age

person = Person('Divyanshu',27)
person.get_age()
person.set_age(29)
person.get_age()
# Out:
# 29

# %%
# Abstraction 
# Concept of hiding internal complex implementation details of an object and 
# only showing necessary features of an object.
# It helps in reducing programming complexity and effort 
from abc import ABC,abstractmethod
class Vehicle(ABC):
    def drive(self):
        print("The vehicle is used for driving")

    @abstractmethod
    def start_engine(self):
        pass
class Car(Vehicle):
    def start_engine(self):
        print("Car engine started")

def operate_vehicle(vehicle):
    vehicle.start_engine()
    vehicle.drive()

car = Car()
operate_vehicle(car)
# Out:
# Car engine started
# The vehicle is used for driving
