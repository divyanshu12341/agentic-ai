# %%
# Text loader
from langchain_community.document_loaders import TextLoader 
loader = TextLoader("speech.txt")
text_documents = loader.load()
text_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='================================================================================\n                    SPEECH BY PRIME MINISTER NARENDRA MODI\n                  ADDRESS TO THE NATION - INDEPENDENCE DAY\n================================================================================\n\nDate: August 15, 2024\nLocation: Red Fort, New Delhi, India\nEvent: 78th Independence Day Address\n\n--------------------------------------------------------------------------------\n1. INTRODUCTION AND SALUTATIONS\n--------------------------------------------------------------------------------\n\nMy dear 140 crore family members,\n\nToday, the world\'s largest democracy is celebrating the grand festival of \nindependence. On this sacred day, from the historic ramparts of the Red Fort, \nI extend my warmest greetings to all citizens of India, both here in the country \nand spread across every corner of the globe. \n\nThis day is an occasion to bow down in reverence to the countless brave souls—the \nfreedom fighters, revolutionaries, and martyrs—who sacrificed their youth, \ntheir comfort, and their lives so that we could breathe the free air of an \nindependent India. We owe an eternal debt of gratitude to Mahatma Gandhi, Netaji \nSubhas Chandra Bose, Sardar Vallabhbhai Patel, Bhagat Singh, Chandrashekhar Azad, \nB.R. Ambedkar, Veer Savarkar, and millions of unnamed heroes of our national movement.\n\n--------------------------------------------------------------------------------\n2. VIKSIT BHARAT @2047: VISION FOR A DEVELOPED NATION\n--------------------------------------------------------------------------------\n\nMy countrymen, we stand at a critical juncture in our nation\'s history. We are \nliving in the \'Amrit Kaal\'—the golden era leading up to 2047, the centenary \nof our nation\'s independence. Our resolve is clear: to transform India into a \nfully developed nation—\'Viksit Bharat\'—by the year 2047.\n\nThis is not merely a government slogan or political ambition; it is the collective \nresolve of 140 crore Indians. Millions of suggestions have poured in from all \nwalks of life—from youth, farmers, women, entrepreneurs, and scholars—outlining \ntheir vision for Viksit Bharat. Their aspirations are our roadmap.\n\nKey Pillars of Viksit Bharat 2047:\n  • Modern and Resilient Infrastructure\n  • Technological Leadership & Digital Transformation\n  • Economic Empowerment of Youth, Women, Farmers, and Marginalized Sections\n  • Energy Independence and Green Transition\n  • Self-Reliance in Defense and High-Tech Manufacturing (Atmanirbhar Bharat)\n\n--------------------------------------------------------------------------------\n3. EMPOWERING YOUTH, INNOVATION AND "DESIGN IN INDIA"\n--------------------------------------------------------------------------------\n\nOur biggest superpower is our demographic dividend. India possesses the youngest \npopulation in the world, with boundless energy, talent, and entrepreneurial spirit. \n\nThrough initiatives like Startup India, Digital India, and the National Education \nPolicy, we have fostered an ecosystem where our youth are no longer just job-seekers, \nbut job-creators. Today, India is home to the third-largest startup ecosystem \nglobally, with young minds innovating across AI, space, biotechnology, fintech, and \nrenewable energy.\n\nI call upon our youth and industries today: It is time to expand from \'Make in India\' \nto \'Design in India\' and \'Create in India\'. Products manufactured and designed \nby Indian minds should setting global standards of quality and reliability.\n\n--------------------------------------------------------------------------------\n4. WOMEN-LED DEVELOPMENT (NARI SHAKTI)\n--------------------------------------------------------------------------------\n\nTrue progress is impossible without the active participation and empowerment of \nour mothers, sisters, and daughters. Today, India is moving b ...

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('speech.pdf')
docs = loader.load()
docs
# Out:
# [Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'PM Narendra Modi Independence Day Speech', 'source': 'speech.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content="OFFICIAL ADDRESS TRANSCRIPT\nSpeech by Prime Minister Narendra Modi\nEvent: 78th Independence Day Address \xa0|\xa0 Date: August 15, 2024 \xa0|\xa0 Location: Red Fort, New Delhi \n1. Introduction and Salutations\nMy dear 140 crore family members,\nToday, the world's largest democracy is celebrating the grand festival of independence. On this sacred day,\nfrom the historic ramparts of the Red Fort, I extend my warmest greetings to all citizens of India, both here\nin the country and spread across every corner of the globe.\nThis day is an occasion to bow down in reverence to the countless brave souls—the freedom fighters,\nrevolutionaries, and martyrs—who sacrificed their youth, their comfort, and their lives so that we could\nbreathe the free air of an independent India. We owe an eternal debt of gratitude to Mahatma Gandhi,\nNetaji  Subhas  Chandra  Bose,  Sardar  Vallabhbhai  Patel,  Bhagat  Singh,  Chandrashekhar  Azad,  B.R.\nAmbedkar , Veer Savarkar , and millions of unnamed heroes of our national movement.\n2. Viksit Bharat @2047: Vision for a Developed Nation\nMy countrymen, we stand at a critical juncture in our nation's history. We are living in the 'Amrit Kaal'—\nthe golden era leading up to 2047, the centenary of our nation's independence. Our resolve is clear: to\ntransform India into a fully developed nation—'Viksit Bharat'—by the year 2047.\nThis is not merely a government slogan or political ambition; it is the collective resolve of 140 crore\nIndians.  Millions  of  suggestions  have  poured  in  from  all  walks  of  life—from  youth,  farmers,  women,\nentrepreneurs, and scholars—outlining their vision for Viksit Bharat. Their aspirations are our roadmap.\nAddress to the Nation — PM Narendra Modi Page 1 of 3"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'PM Narendra Modi Independence Day Speech', 'source': 'speech.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Key Pillars of Viksit Bharat 2047\nModern and Resilient Infrastructure: Expanding connectivity across rural and urban\nlandscapes.\nTechnological Leadership & Digital Transformation: Harnessing AI, semiconductor production,\nand digital public goods.\nEconomic Empowerment: Targeted growth for youth, women, farmers, and marginalized\nsections.\nEnergy Independence & Green Transition: Accelerating solar , wind, and green hydrogen\nadoption.\nSelf-Reliance (Atmanirbhar Bharat): Strengthening domestic defense and high-tech\nmanufacturing.\n3. Empowering Youth, Innovation and "Design in India"\nOur biggest superpower is our demographic dividend. India possesses the youngest population in the\nworld, with boundless energy, talent, and entrepreneurial spirit.\nThrough initiatives like Startup India, Digital India, and the National Education Policy, we have fostered an\necosystem where our youth are no longer just job-seekers, but job-creators. Today, India is home to the\nthird-largest startup ecosystem globally, with young minds innovating across AI, space, biotechnology,\nfintech, and renewable energy.\n"I call upon our youth and industries today: It is time to expand from \'Make in India\' to \'Design in India\'\nand \'Create in India\'. Products manufactured and designed by Indian minds should set global standards\nof quality and reliability." \n4. Women-Led Development (Nari Shakti)\nTrue progress is impossible without the active participation and empowerment of our mothers, sisters, and\ndaughters. Today, India is moving beyond woman empowerment to \'Women-Led Development\'.\nFrom the cockpit of fighter jets to space research at ISRO, from sports platforms globally to grass-root self-\nhelp groups (SHGs) in remote villages, Indian women are leading from the front. Through programs like\n\'Lakhpati Didi\', millions of rural women are attaining financial independence and becoming a pillar of\nstrength for local economies.\n5. Self-Reliance & Economic Resilience (Atmanirbhar Bharat)\nIn  recent  years,  the  world  has  experienced  global  supply  chain  disruptions,  wars,  and  economic\nuncertainties. Amidst these challenges, India has proven to be a beacon of economic stability and growth.\n• \n• \n• \n• \n• \nAddress to the Nation — PM Narendra Modi Page 2 of 3'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'title': 'PM Narendra Modi Independence Day Speech', 'source': 'speech.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='We have made significant strides in self-reliance:\nDefense Manufacturing: India is now exporting defense equipment to over 80 nations.\nSemiconductors & Tech: Establishing semiconductor fabrication plants locally to reduce import\ndependency.\nRenewable Energy: Achieving ambitious solar , wind, and green hydrogen targets well ahead of\nscheduled deadlines.\nAgriculture: Modernizing agricultural practices, supporting natural farming, and enhancing food\nprocessing networks.\n6. Reforms, Performance, and Transformation\nOur governance mantra remains firm: "Reform, Perform, and Transform."\nWe  have  dismantled  hundreds  of  obsolete  laws,  streamlined  regulatory  frameworks,  and  accelerated\nadministrative processes. Corruption and nepotism are being rooted out with zero tolerance. Bureaucracy\nis  being  made  more  accountable,  transparent,  and  responsive  through  technology  and  digital  public\ninfrastructure (UPI, Aadhaar , DigiLocker).\nOur goal is simple: Ease of Living for every citizen, and Ease of Doing Business for every entrepreneur and\ninvestor .\n7. Conclusion & Call to Action\nMy dear citizens,\nThe path to 2047 requires dedication, hard work, and national unity (\'Ek Bharat, Shreshtha Bharat\'). Let us\ncommit ourselves to duty. Every small step taken by 140 crore people becomes a giant leap of 140 crore\nsteps forward for the nation.\nLet us march ahead with confidence, courage, and pride in our heritage while embracing modern scientific\ntemper and progress.\nVictory to Mother India! (Bharat Mata Ki Jai!)\nLong Live Freedom! (Vande Mataram!)\nJai Hind!\n1. \n2. \n3. \n4. \nAddress to the Nation — PM Narendra Modi Page 3 of 3')]

# %%
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %%
# Web based loader 
from langchain_community.document_loaders import WebBaseLoader
import bs4
loader = WebBaseLoader(web_path=('https://reference.langchain.com/python/langchain-community/document_loaders/web_base/WebBaseLoader',),
                                 bs_kwargs = dict(parse_only = bs4.SoupStrainer(
                                     class_=("markdown-content")
                                 )))

loader.load()
# Out:
# [Document(metadata={'source': 'https://reference.langchain.com/python/langchain-community/document_loaders/web_base/WebBaseLoader'}, page_content='')]
